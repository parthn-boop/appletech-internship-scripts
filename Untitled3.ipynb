# %%
data = pd.read_csv("../input/ecommerce-data/data.csv", encoding="ISO -8859-1", dtype={'CustomerID': str})
# Out:
# --------------------------------------------------------------------------
# NameError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data = pd.read_csv("../input/ecommerce-data/data.csv", encoding="ISO -8859-1", dtype={'CustomerID': str})
#
# NameError: name 'pd' is not defined

# %%
python -m notebook
# Out:
#   Cell In[2], line 1
#     python -m notebook
#               ^
# SyntaxError: invalid syntax

# %%
python -m jupyter notebook
# Out:
#   Cell In[3], line 1
#     python -m jupyter notebook
#               ^
# SyntaxError: invalid syntax

# %%
data = pd.read_csv("../input/ecommerce-data/data.csv", encoding="ISO -8859-1", dtype={'CustomerID': str})
# Out:
# --------------------------------------------------------------------------
# NameError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data = pd.read_csv("../input/ecommerce-data/data.csv", encoding="ISO -8859-1", dtype={'CustomerID': str})
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %matplotlib inline
sns.set(style="whitegrid")

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import missingno as msno

# %%
# %matplotlib inline
sns.set(style="whitegrid")

# %%
import pandas as pd

# %%
data = pd.read_csv(
    "C:/Users/modin/OneDrive/Documents/my-notebooks/ecommerce-data/data.csv",
    encoding="ISO-8859-1",
    dtype={'CustomerID': str}
)
# Out:
# --------------------------------------------------------------------------
# FileNotFoundError                        Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 data = pd.read_csv(
#       2     "C:/Users/modin/OneDrive/Documents/my-notebooks/ecommerce-data/data.csv",
#       3     encoding="ISO-8859-1",
#       4     dtype={'CustomerID': str}
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd

data = pd.read_csv(
    "C:/Users/modin/OneDrive/Documents/my-notebooks/ecommerce-data/data.csv",
    encoding="ISO-8859-1",   
    dtype={'CustomerID': str}
)
# Out:
# --------------------------------------------------------------------------
# FileNotFoundError                        Traceback (most recent call last)
# Cell In[14], line 3
#       1 import pandas as pd
#       2
# ----> 3 data = pd.read_csv(
#       4     "C:/Users/modin/OneDrive/Documents/my-notebooks/ecommerce-data/data.csv",
#       5     encoding="ISO-8859-1",
#       6     dtype={'CustomerID': str}
#
# ...
