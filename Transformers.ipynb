# %%
# !pip uninstall transformers -y
# !pip install transformers==4.38.2
# !pip install torch
# Out:
# Found existing installation: transformers 4.38.2
# Uninstalling transformers-4.38.2:
#   Successfully uninstalled transformers-4.38.2
# Defaulting to user installation because normal site-packages is not writeable
# Collecting transformers==4.38.2
#   Using cached transformers-4.38.2-py3-none-any.whl.metadata (130 kB)
# Requirement already satisfied: filelock in c:\users\modin\appdata\roaming\python\python312\site-packages (from transformers==4.38.2) (3.29.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in c:\users\modin\appdata\roaming\python\python312\site-packages (from transformers==4.38.2) (0.36.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\modin\appdata\roaming\python\python312\site-packages (from transformers==4.38.2) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\modin\appdata\roaming\python\python312\site-packages (from transformers==4.38.2) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\modin\appdata\roaming\python\python312\site-packages (from transformers==4.38.2) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\modin\appdata\roaming\python\python312\site-packages (from transformers==4.38.2) (2026.5.9)
# Requirement already satisfied: requests in c:\users\modin\appdata\roaming\python\python312\site-packages (from transformers==4.38.2) (2.34.2)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\modin\appdata\roaming\python\python312\site-packages (from transformers==4.38.2) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\modin\appdata\roaming\python\python312\site-packages (from transformers==4.38.2) (0.8.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\modin\appdata\roaming\python\python312\site-packages (from transformers==4.38.2) (4.67.3)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\modin\appdata\roaming\python\python312\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.38.2) (2026.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\modin\appdata\roaming\python\python312\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.38.2) (4.15.0)
# Requirement already satisfied: colorama in c:\users\modin\appdata\roaming\python\python312\site-packages (from tqdm>=4.27->transformers==4.38.2) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\modin\appdata\roaming\python\python312\site-packages (from requests->transformers==4.38.2) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\modin\appdata\roaming\python\python312\site-packages (from requests->transformers==4.38.2) (3.15)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\modin\appdata\roaming\python\python312\site-packages (from requests->transformers==4.38.2) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\modin\appdata\roaming\python\python312\site-packages (from requests->transformers==4.38.2) (2026.4.22)
# Using cached transformers-4.38.2-py3-none-any.whl (8.5 MB)
# Installing collected packages: transformers
# Successfully installed transformers-4.38.2
#   WARNING: The script transformers-cli.exe is installed in 'C:\Users\modin\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 5.6.0 requires transformers<6.0.0,>=4.41.0, but you have transformers 4.38.2 which is incompatible.
#
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in c:\users\modin\appdata\roaming\python\python312\site-packages (2.12.0)
# Requirement already satisfied: filelock in c:\users\modin\appdata\roaming\python\python312\site-packages (from torch) (3.29.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\modin\appdata\roaming\python\python312\site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in c:\users\modin\appdata\roaming\python\python312\site-packages (from torch) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\modin\appdata\roaming\python\python312\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\modin\appdata\roaming\python\python312\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\modin\appdata\roaming\python\python312\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\modin\appdata\roaming\python\python312\site-packages (from torch) (2026.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\modin\appdata\roaming\python\python312\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\modin\appdata\roaming\python\python312\site-packages (from jinja2->torch) (3.0.3)
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from transformers import pipeline

sentiment = pipeline("sentiment-analysis")

print(sentiment("I love machine learning"))
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# [{'label': 'POSITIVE', 'score': 0.9997808337211609}]

# %%
from transformers import pipeline

qa = pipeline(
    "question-answering",
    model="distilbert-base-cased-distilled-squad"
)

context = "Transformers use attention mechanisms in deep learning."
question = "What do transformers use?"

print(qa(question=question, context=context))
# Out:
# {'score': 0.9589791297912598, 'start': 17, 'end': 37, 'answer': 'attention mechanisms'}

# %%
from transformers import pipeline

qa = pipeline(
    "text2text-generation",
    model="google/flan-t5-base"
)

prompt = """
Question: What is Deep Learning?
Explain it
"""

result = qa(
    prompt,
    max_length=120,
    truncation=True
)

print("Answer:", result[0]['generated_text'])
# Out:
# Answer: a computer science program
